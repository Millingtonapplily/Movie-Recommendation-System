# %% [markdown]
# # Introduction

# %% [markdown]
# Recommender systems are well-studied and proven to provide tremendous values to internet businesses and their consumers.In this project, I use amazon sagemaker to build a movie recommendation system, which can provide top 5 recommendation movies for users.
#
#
# I first created a Factorization Matrix model, and then extend it to a knn model using Amazon sagemaker's built-in algorithm. I deployed the knn model using batch transformation, which gives resultd for all users.
#
# I then tried to use ALS in Pyspark millib to build another recommendation model. After searching online, I found that sagemaker has no built-in image for ALS, so I need to use docker to build my own algorithm, upload the container on EC2, and run it on sagemaker. I did not managed to have the docker successfully run in the sagemaker, but I still want to include the code that I use to build the ALS recommendor.

# %% [markdown]
# # Content
# * [1. Binary Classifier: Factorization Machines](#1.-Binary-Classifier:-Factorization-Machines)
#     * [1.1 Set up environment ](#1.1-Set-up-environment)
#     * [1.2 Data Preparation ](#1.2-Data-Preparation)
#     * [1.3 Build a Factorization Machine (FM) Model ](#1.3-Build-a-Factorization-Machine-(FM)-Model)
#     * [1.4 Convert to Protobuf ](#1.4-Convert-to-Protobuf)
#     * [1.5 Run the job and save it on S3 ](#1.5-Run-the-job-and-save-it-on-S3)
# * [2. KNN model](#2.-KNN-model)
#     * [2.1 Download the model data ](#2.1-Download-the-model-data)
#     * [2.2 Extract model data to create user and item latent matrices ](#2.2-Extract-model-data-to-create-user-and-item-latent-matrices)
#     * [2.3 Build K-Nearest-Neighbour Model ](#2.3-Build-K-Nearest-Neighbour-Model)
#     * [2.4 Deploy with Batch Transformation ](#2.4-Deploy-with-Batch-Transformation)
#     * [2.5 User predictions ](#2.5-User-predictions)
# * [3. ALS Model](#3.-ALS-Model)
#     * [3.1 Use Sagemaker Pyspark SDK](#3.1-Use-Sagemaker-Pyspark-SDK)
#     * [3.2 ALS training](#3.2-ALS-training)
#     * [3.3 ALS model selection and Evaluation](#3.3-ALS-model-selection-and-Evaluation)
#     * [3.4 Model Testing](#3.4-Model-Testing)

# %% [markdown]
# ## Binary Classifier: Factorization Machines

# %% [markdown]
# ### Set up environment

# %%
# import libraries
import boto3, re, sys, math, json, os, io, sagemaker, urllib.request
from sagemaker import get_execution_role
import numpy as np                                
import pandas as pd                                                          
from time import gmtime, strftime                 
from sagemaker.predictor import csv_serializer
import sagemaker.amazon.common as smac
from sagemaker.amazon.amazon_estimator import get_image_uri
from scipy.sparse import lil_matrix

# Define IAM role
role = get_execution_role()

containers = {'us-west-2': '174872318107.dkr.ecr.us-west-2.amazonaws.com/factorization-machines:latest',
              'us-east-1': '382416733822.dkr.ecr.us-east-1.amazonaws.com/factorization-machines:latest',
              'us-east-2': '404615174143.dkr.ecr.us-east-2.amazonaws.com/factorization-machines:latest',
              'eu-west-1': '438346466558.dkr.ecr.eu-west-1.amazonaws.com/factorization-machines:latest'}

# set the region of the instance
my_region = boto3.session.Session().region_name
print("Success - the MySageMakerInstance is in the " + my_region + " region. You will use the " + containers[my_region] + " container for your SageMaker endpoint.")
# Out:
# Success - the MySageMakerInstance is in the us-east-2 region. You will use the 404615174143.dkr.ecr.us-east-2.amazonaws.com/factorization-machines:latest container for your SageMaker endpoint.

# %% [markdown]
# ### Data Preparation
# Fetch the data from Movielens.

# %%
#download data
# !wget http://files.grouplens.org/datasets/movielens/ml-100k.zip
# !unzip -o ml-100k.zip
# Out:
# --2020-04-06 06:51:44--  http://files.grouplens.org/datasets/movielens/ml-100k.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4924029 (4.7M) [application/zip]
# Saving to: ‘ml-100k.zip.1’
#
# ml-100k.zip.1       100%[===================>]   4.70M  5.38MB/s    in 0.9s
#
# 2020-04-06 06:51:45 (5.38 MB/s) - ‘ml-100k.zip.1’ saved [4924029/4924029]
#
# Archive:  ml-100k.zip
#   inflating: ml-100k/allbut.pl
#   inflating: ml-100k/mku.sh
#   inflating: ml-100k/README
#   inflating: ml-100k/u.data
#   inflating: ml-100k/u.genre
#   inflating: ml-100k/u.info
#   inflating: ml-100k/u.item
#   inflating: ml-100k/u.occupation
#   inflating: ml-100k/u.user
#   inflating: ml-100k/u1.base
#   inflating: ml-100k/u1.test
#   inflating: ml-100k/u2.base
#   inflating: ml-100k/u2.test
#   inflating: ml-100k/u3.base
#   inflating: ml-100k/u3.test
#   inflating: ml-100k/u4.base
#   inflating: ml-100k/u4.test
#   inflating: ml-100k/u5.base
#   inflating: ml-100k/u5.test
#   inflating: ml-100k/ua.base
#   inflating: ml-100k/ua.test
#   inflating: ml-100k/ub.base
#   inflating: ml-100k/ub.test

# %% [markdown]
# The ml-100k file contains lots of movie datasets. In this section, I will use ua.base to train a Factorization Machines (FM) Model and ua.test for testing. Before loading the dataset, I would like to shuffle it.

# %%
# %cd ml-100k
# !shuf ua.base -o ua.base.shuffled
# Out:
# /home/ec2-user/SageMaker/ml-100k

# %% [markdown]
# Load training and test data to instance.

# %%
# Load training data
user_movie_ratings_train = pd.read_csv('ua.base.shuffled', sep='\t', index_col=False, 
                 names=['user_id' , 'movie_id' , 'rating'])
user_movie_ratings_train.head(5)
# Out:
#    user_id  movie_id  rating
# 0      198       237       2
# 1      460       137       5
# 2      458       762       3
# 3      289       125       2
# 4      450       781       4

# %%
# Load test data
user_movie_ratings_test = pd.read_csv('ua.test', sep='\t', index_col=False, 
                 names=['user_id' , 'movie_id' , 'rating'])
user_movie_ratings_test.head(5)
# Out:
#    user_id  movie_id  rating
# 0        1        20       4
# 1        1        33       4
# 2        1        61       4
# 3        1       117       3
# 4        1       155       2

# %%
# Preview of the dataset
nb_users= user_movie_ratings_train['user_id'].max()
nb_movies=user_movie_ratings_train['movie_id'].max()
nb_features=nb_users+nb_movies
nb_ratings_test=len(user_movie_ratings_test.index)
nb_ratings_train=len(user_movie_ratings_train.index)
print(" # of users: ", nb_users)
print(" # of movies: ", nb_movies)
print(" Training Count: ", nb_ratings_train)
print(" Test Count: ", nb_ratings_test)
print(" Features (# of users + # of movies): ", nb_features)
# Out:
#  # of users:  943
#  # of movies:  1682
#  Training Count:  90570
#  Test Count:  9430
#  Features (# of users + # of movies):  2625

# %% [markdown]
# ### Build a Factorization Machine (FM) Model
# We can start the work by building a simple model, Factorization Machine, a binary recommendor, which tells you whether the user like it or not. To build a one-hot encoded sparse matrix as input for FM model, we define ratings over 4 and above are considered as 1, and ratings 3 and below as 0.

# %%
def loadDataset(df, lines, columns):
    # Features are one-hot encoded in a sparse matrix
    X = lil_matrix((lines, columns)).astype('float32')
    # Labels are stored in a vector
    Y = []
    line=0
    for index, row in df.iterrows():
            X[line,row['user_id']-1] = 1
            X[line, nb_users+(row['movie_id']-1)] = 1
            if int(row['rating']) >= 4:
                Y.append(1)
            else:
                Y.append(0)
            line=line+1

    Y=np.array(Y).astype('float32')            
    return X,Y


X_train, Y_train = loadDataset(user_movie_ratings_train, nb_ratings_train, nb_features)
X_test, Y_test = loadDataset(user_movie_ratings_test, nb_ratings_test, nb_features)

# %%
print(X_train.shape)
print(Y_train.shape)
assert X_train.shape == (nb_ratings_train, nb_features)
assert Y_train.shape == (nb_ratings_train, )
zero_labels = np.count_nonzero(Y_train)
print("Training labels: %d zeros, %d ones" % (zero_labels, nb_ratings_train-zero_labels))

print(X_test.shape)
print(Y_test.shape)
assert X_test.shape  == (nb_ratings_test, nb_features)
assert Y_test.shape  == (nb_ratings_test, )
zero_labels = np.count_nonzero(Y_test)
print("Test labels: %d zeros, %d ones" % (zero_labels, nb_ratings_test-zero_labels))
# Out:
# (90570, 2625)
# (90570,)
# Training labels: 49906 zeros, 40664 ones
# (9430, 2625)
# (9430,)
# Test labels: 5469 zeros, 3961 ones

# %% [markdown]
# ### Convert to Protobuf

# %%
bucket = 'movie-recom-sys-0420'
prefix = 'fm'

train_key      = 'train.protobuf'
train_prefix   = '{}/{}'.format(prefix, 'train')

test_key       = 'test.protobuf'
test_prefix    = '{}/{}'.format(prefix, 'test')

output_prefix  = 's3://{}/{}/output'.format(bucket, prefix)

# %%
def writeDatasetToProtobuf(X, bucket, prefix, key, d_type, Y=None):
    buf = io.BytesIO()
    if d_type == "sparse":
        smac.write_spmatrix_to_sparse_tensor(buf, X, labels=Y)
    else:
        smac.write_numpy_to_dense_tensor(buf, X, labels=Y)
        
    buf.seek(0)
    obj = '{}/{}'.format(prefix, key)
    boto3.resource('s3').Bucket(bucket).Object(obj).upload_fileobj(buf)
    return 's3://{}/{}'.format(bucket,obj)
    
fm_train_data_path = writeDatasetToProtobuf(X_train, bucket, train_prefix, train_key, "sparse", Y_train)    
fm_test_data_path  = writeDatasetToProtobuf(X_test, bucket, test_prefix, test_key, "sparse", Y_test)    
  
print("Training data S3 path: ",fm_train_data_path)
print("Test data S3 path: ",fm_test_data_path)
print("FM model output S3 path: {}".format(output_prefix))
# Out:
# Training data S3 path:  s3://movie-recom-sys-0420/fm/train/train.protobuf
# Test data S3 path:  s3://movie-recom-sys-0420/fm/test/test.protobuf
# FM model output S3 path: s3://movie-recom-sys-0420/fm/output

# %% [markdown]
# ### Run the job
# To run the job on sagemaker, I first creat an Estimator based on the FM container available in my AWS Region. Then, I have to set some FM-specific hyperparameters:
#
# - feature_dim: the number of features in each sample (2,625 in this case).
# - predictor_type: ‘binary_classifier'.
# - num_factors: the common dimension for the user and item matrices.
#
# After 50 epochs, test accuracy is 69.5% and the F1 score (a typical metric for a binary classifier) is 0.736 (1 indicates a perfect classifier). Not great, but with all that sparse matrix and protobuf excitement.

# %%
instance_type='ml.m4.xlarge'
fm = sagemaker.estimator.Estimator(get_image_uri(boto3.Session().region_name, "factorization-machines"),
                                   get_execution_role(), 
                                   train_instance_count=1, 
                                   train_instance_type=instance_type,
                                   output_path=output_prefix,
                                   sagemaker_session=sagemaker.Session())

fm.set_hyperparameters(feature_dim=nb_features,
                      predictor_type='binary_classifier',
                      mini_batch_size=1000,
                      num_factors=64,
                      epochs=100)

fm.fit({'train': fm_train_data_path, 'test': fm_test_data_path})
# Out:
# 2020-04-14 02:33:06 Starting - Starting the training job...
# 2020-04-14 02:33:07 Starting - Launching requested ML instances...
# 2020-04-14 02:34:05 Starting - Preparing the instances for training......
# 2020-04-14 02:34:54 Downloading - Downloading input data......
# 2020-04-14 02:35:57 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# /opt/amazon/lib/python2.7/site-packages/pandas/util/nosetester.py:13: DeprecationWarning: Importing from numpy.testing.nosetester is deprecated, import from numpy.testing instead.
#   from numpy.testing import nosetester
# [04/14/2020 02:35:59 INFO 139834076616512] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'factors_lr': u'0.0001', u'linear_init_sigma': u'0.01', u'epochs': 1, u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'0.001', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.001', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'', u'bias_wd': u'0.01', u'use_linear': u'true', u'bias_lr': u'0.1', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'bias_init_sigma': u'0.01', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'0.00001', u'linear_wd': u'0.001', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
# [04/14/2020 02:35:59 INFO 139834076616512] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'100', u'feature_dim': u'2625', u'mini_batch_size': u'1000', u'predictor_type': u'binary_classifier', u'num_factors': u'64'}
# [04/14/2020 02:35:59 INFO 139834076616512] Final configuration: {u'factors_lr': u'0.0001', u'linear_init_sigma': u'0.01', u'epochs': u'100', u'feature_dim': u'2625', u'num_factors': u'64', u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'0.001', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.001', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'', u'bias_wd': u'0.01', u'use_linear': u'true', u'bias_lr': u'0.1', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'predictor_type': u'binary_classifier', u'bias_init_sigma': u'0.01', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'0.00001', u'linear_wd': u'0.001', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
# [04/14/2020 02:35:59 WARNING 139834076616512] Loggers have already been setup.
# Process 1 is a worker.
# [04/14/2020 02:35:59 INFO 139834076616512] Using default worker.
# [2020-04-14 02:35:59.619] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-04-14 02:35:59.628] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 13, "num_examples": 1, "num_bytes": 64000}
# [04/14/2020 02:35:59 INFO 139834076616512] nvidia-smi took: 0.0251801013947 secs to identify 0 gpus
# [04/14/2020 02:35:59 INFO 139834076616512] Number of GPUs being used: 0
# [04/14/2020 02:35:59 INFO 139834076616512] [Sparse network] Building a sparse network.
# [04/14/2020 02:35:59 INFO 139834076616512] Create Store: local
# #metrics {"Metrics": {"initialize.time": {"count": 1, "max": 38.043975830078125, "sum": 38.043975830078125, "min": 38.043975830078125}}, "EndTime": 1586831759.663521, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831759.614668}
#
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 1000, "sum": 1000.0, "min": 1000}, "Max Records Seen Between Resets": {"count": 1, "max": 1000, "sum": 1000.0, "min": 1000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1586831759.663733, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831759.663678}
#
# [02:35:59] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.1.x.202841.0/AL2012/generic-flavor/src/src/kvstore/./kvstore_local.h:280: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use row_sparse_pull with row_ids.
# [02:35:59] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.1.x.202841.0/AL2012/generic-flavor/src/src/kvstore/./kvstore_local.h:280: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use row_sparse_pull with row_ids.
# [04/14/2020 02:35:59 INFO 139834076616512] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_classification_accuracy <score>=0.532
# [04/14/2020 02:35:59 INFO 139834076616512] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_classification_cross_entropy <loss>=0.692519165039
# [04/14/2020 02:35:59 INFO 139834076616512] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_f_1.000 <score>=0.678129298487
# [2020-04-14 02:36:00.553] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 2, "duration": 864, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:00 INFO 139834076616512] #quality_metric: host=algo-1, epoch=0, train binary_classification_accuracy <score>=0.548692307692
# [04/14/2020 02:36:00 INFO 139834076616512] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy <loss>=0.683872998583
# [04/14/2020 02:36:00 INFO 139834076616512] #quality_metric: host=algo-1, epoch=0, train binary_f_1.000 <score>=0.708364400702
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 100, "sum": 100.0, "min": 100}, "update.time": {"count": 1, "max": 889.8611068725586, "sum": 889.8611068725586, "min": 889.8611068725586}}, "EndTime": 1586831760.553817, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831759.663603}
#
# [04/14/2020 02:36:00 INFO 139834076616512] #progress_metric: host=algo-1, completed 1 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 92, "sum": 92.0, "min": 92}, "Total Records Seen": {"count": 1, "max": 91570, "sum": 91570.0, "min": 91570}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1586831760.554124, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 0}, "StartTime": 1586831759.663915}
#
# [04/14/2020 02:36:00 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=101725.391301 records/second
# [04/14/2020 02:36:00 INFO 139834076616512] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_classification_accuracy <score>=0.52
# [04/14/2020 02:36:00 INFO 139834076616512] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_classification_cross_entropy <loss>=0.681876220703
# [04/14/2020 02:36:00 INFO 139834076616512] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_f_1.000 <score>=0.684210526316
# [2020-04-14 02:36:01.368] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 812, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:01 INFO 139834076616512] #quality_metric: host=algo-1, epoch=1, train binary_classification_accuracy <score>=0.564362637363
# [04/14/2020 02:36:01 INFO 139834076616512] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy <loss>=0.673722536192
# [04/14/2020 02:36:01 INFO 139834076616512] #quality_metric: host=algo-1, epoch=1, train binary_f_1.000 <score>=0.713137233619
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 814.769983291626, "sum": 814.769983291626, "min": 814.769983291626}}, "EndTime": 1586831761.369564, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831760.55392}
#
# [04/14/2020 02:36:01 INFO 139834076616512] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 183, "sum": 183.0, "min": 183}, "Total Records Seen": {"count": 1, "max": 182140, "sum": 182140.0, "min": 182140}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1586831761.369907, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 1}, "StartTime": 1586831760.554749}
#
# [04/14/2020 02:36:01 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=111085.216036 records/second
# [04/14/2020 02:36:01 INFO 139834076616512] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_classification_accuracy <score>=0.573
# [04/14/2020 02:36:01 INFO 139834076616512] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_classification_cross_entropy <loss>=0.670642211914
# [04/14/2020 02:36:01 INFO 139834076616512] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_f_1.000 <score>=0.706529209622
# [2020-04-14 02:36:02.256] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 882, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:02 INFO 139834076616512] #quality_metric: host=algo-1, epoch=2, train binary_classification_accuracy <score>=0.600428571429
# [04/14/2020 02:36:02 INFO 139834076616512] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy <loss>=0.664291426774
# [04/14/2020 02:36:02 INFO 139834076616512] #quality_metric: host=algo-1, epoch=2, train binary_f_1.000 <score>=0.728054626908
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 886.2810134887695, "sum": 886.2810134887695, "min": 886.2810134887695}}, "EndTime": 1586831762.257128, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831761.369665}
#
# [04/14/2020 02:36:02 INFO 139834076616512] #progress_metric: host=algo-1, completed 3 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 274, "sum": 274.0, "min": 274}, "Total Records Seen": {"count": 1, "max": 272710, "sum": 272710.0, "min": 272710}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1586831762.257415, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 2}, "StartTime": 1586831761.370807}
#
# [04/14/2020 02:36:02 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=102134.245653 records/second
# [04/14/2020 02:36:02 INFO 139834076616512] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_classification_accuracy <score>=0.651
# [04/14/2020 02:36:02 INFO 139834076616512] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_classification_cross_entropy <loss>=0.661264404297
# [04/14/2020 02:36:02 INFO 139834076616512] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_f_1.000 <score>=0.741672834937
# [2020-04-14 02:36:02.988] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 728, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:02 INFO 139834076616512] #quality_metric: host=algo-1, epoch=3, train binary_classification_accuracy <score>=0.634384615385
# [04/14/2020 02:36:02 INFO 139834076616512] #quality_metric: host=algo-1, epoch=3, train binary_classification_cross_entropy <loss>=0.655524557596
# [04/14/2020 02:36:02 INFO 139834076616512] #quality_metric: host=algo-1, epoch=3, train binary_f_1.000 <score>=0.741063576437
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 730.9999465942383, "sum": 730.9999465942383, "min": 730.9999465942383}}, "EndTime": 1586831762.989185, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831762.257227}
#
# [04/14/2020 02:36:02 INFO 139834076616512] #progress_metric: host=algo-1, completed 4 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 365, "sum": 365.0, "min": 365}, "Total Records Seen": {"count": 1, "max": 363280, "sum": 363280.0, "min": 363280}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1586831762.989424, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 3}, "StartTime": 1586831762.25815}
#
# [04/14/2020 02:36:02 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=123829.10966 records/second
# [04/14/2020 02:36:03 INFO 139834076616512] #quality_metric: host=algo-1, epoch=4, batch=0 train binary_classification_accuracy <score>=0.694
# [04/14/2020 02:36:03 INFO 139834076616512] #quality_metric: host=algo-1, epoch=4, batch=0 train binary_classification_cross_entropy <loss>=0.652516357422
# [04/14/2020 02:36:03 INFO 139834076616512] #quality_metric: host=algo-1, epoch=4, batch=0 train binary_f_1.000 <score>=0.758293838863
# [2020-04-14 02:36:03.716] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 725, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:03 INFO 139834076616512] #quality_metric: host=algo-1, epoch=4, train binary_classification_accuracy <score>=0.659131868132
# [04/14/2020 02:36:03 INFO 139834076616512] #quality_metric: host=algo-1, epoch=4, train binary_classification_cross_entropy <loss>=0.647297048715
# [04/14/2020 02:36:03 INFO 139834076616512] #quality_metric: host=algo-1, epoch=4, train binary_f_1.000 <score>=0.750070501406
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 727.4038791656494, "sum": 727.4038791656494, "min": 727.4038791656494}}, "EndTime": 1586831763.717514, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831762.989272}
#
# [04/14/2020 02:36:03 INFO 139834076616512] #progress_metric: host=algo-1, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 456, "sum": 456.0, "min": 456}, "Total Records Seen": {"count": 1, "max": 453850, "sum": 453850.0, "min": 453850}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1586831763.71789, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 4}, "StartTime": 1586831762.990073}
#
# [04/14/2020 02:36:03 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=124414.650294 records/second
# [04/14/2020 02:36:03 INFO 139834076616512] #quality_metric: host=algo-1, epoch=5, batch=0 train binary_classification_accuracy <score>=0.695
# [04/14/2020 02:36:03 INFO 139834076616512] #quality_metric: host=algo-1, epoch=5, batch=0 train binary_classification_cross_entropy <loss>=0.644381469727
# [04/14/2020 02:36:03 INFO 139834076616512] #quality_metric: host=algo-1, epoch=5, batch=0 train binary_f_1.000 <score>=0.751426242869
# [2020-04-14 02:36:04.456] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 12, "duration": 735, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:04 INFO 139834076616512] #quality_metric: host=algo-1, epoch=5, train binary_classification_accuracy <score>=0.676043956044
# [04/14/2020 02:36:04 INFO 139834076616512] #quality_metric: host=algo-1, epoch=5, train binary_classification_cross_entropy <loss>=0.639635441036
# [04/14/2020 02:36:04 INFO 139834076616512] #quality_metric: host=algo-1, epoch=5, train binary_f_1.000 <score>=0.755758077879
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 738.1300926208496, "sum": 738.1300926208496, "min": 738.1300926208496}}, "EndTime": 1586831764.456737, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831763.717627}
#
# [04/14/2020 02:36:04 INFO 139834076616512] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 547, "sum": 547.0, "min": 547}, "Total Records Seen": {"count": 1, "max": 544420, "sum": 544420.0, "min": 544420}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1586831764.456999, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 5}, "StartTime": 1586831763.71858}
#
# [04/14/2020 02:36:04 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=122632.866365 records/second
# [04/14/2020 02:36:04 INFO 139834076616512] #quality_metric: host=algo-1, epoch=6, batch=0 train binary_classification_accuracy <score>=0.711
# [04/14/2020 02:36:04 INFO 139834076616512] #quality_metric: host=algo-1, epoch=6, batch=0 train binary_classification_cross_entropy <loss>=0.636861022949
# [04/14/2020 02:36:04 INFO 139834076616512] #quality_metric: host=algo-1, epoch=6, batch=0 train binary_f_1.000 <score>=0.757346767422
# [2020-04-14 02:36:05.126] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 14, "duration": 667, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=6, train binary_classification_accuracy <score>=0.689208791209
# [04/14/2020 02:36:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=6, train binary_classification_cross_entropy <loss>=0.632541536771
# [04/14/2020 02:36:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=6, train binary_f_1.000 <score>=0.760261083326
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 669.0418720245361, "sum": 669.0418720245361, "min": 669.0418720245361}}, "EndTime": 1586831765.126684, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831764.456828}
#
# [04/14/2020 02:36:05 INFO 139834076616512] #progress_metric: host=algo-1, completed 7 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 638, "sum": 638.0, "min": 638}, "Total Records Seen": {"count": 1, "max": 634990, "sum": 634990.0, "min": 634990}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1586831765.12692, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 6}, "StartTime": 1586831764.45761}
#
# [04/14/2020 02:36:05 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=135293.768321 records/second
# [04/14/2020 02:36:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=7, batch=0 train binary_classification_accuracy <score>=0.714
# [04/14/2020 02:36:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=7, batch=0 train binary_classification_cross_entropy <loss>=0.629934448242
# [04/14/2020 02:36:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=7, batch=0 train binary_f_1.000 <score>=0.753872633391
# [2020-04-14 02:36:05.819] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 16, "duration": 690, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=7, train binary_classification_accuracy <score>=0.697736263736
# [04/14/2020 02:36:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=7, train binary_classification_cross_entropy <loss>=0.625995451204
# [04/14/2020 02:36:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=7, train binary_f_1.000 <score>=0.762662432913
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 692.6059722900391, "sum": 692.6059722900391, "min": 692.6059722900391}}, "EndTime": 1586831765.820282, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831765.126765}
#
# [04/14/2020 02:36:05 INFO 139834076616512] #progress_metric: host=algo-1, completed 8 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 729, "sum": 729.0, "min": 729}, "Total Records Seen": {"count": 1, "max": 725560, "sum": 725560.0, "min": 725560}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1586831765.820552, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 7}, "StartTime": 1586831765.127642}
#
# [04/14/2020 02:36:05 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=130680.531944 records/second
# [04/14/2020 02:36:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=8, batch=0 train binary_classification_accuracy <score>=0.716
# [04/14/2020 02:36:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=8, batch=0 train binary_classification_cross_entropy <loss>=0.623566711426
# [04/14/2020 02:36:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=8, batch=0 train binary_f_1.000 <score>=0.752181500873
# [2020-04-14 02:36:06.481] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 18, "duration": 658, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:06 INFO 139834076616512] #quality_metric: host=algo-1, epoch=8, train binary_classification_accuracy <score>=0.70467032967
# [04/14/2020 02:36:06 INFO 139834076616512] #quality_metric: host=algo-1, epoch=8, train binary_classification_cross_entropy <loss>=0.619965682816
# [04/14/2020 02:36:06 INFO 139834076616512] #quality_metric: host=algo-1, epoch=8, train binary_f_1.000 <score>=0.764722876378
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 660.6621742248535, "sum": 660.6621742248535, "min": 660.6621742248535}}, "EndTime": 1586831766.481877, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831765.820371}
#
# [04/14/2020 02:36:06 INFO 139834076616512] #progress_metric: host=algo-1, completed 9 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 820, "sum": 820.0, "min": 820}, "Total Records Seen": {"count": 1, "max": 816130, "sum": 816130.0, "min": 816130}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1586831766.482162, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 8}, "StartTime": 1586831765.821187}
#
# [04/14/2020 02:36:06 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=136997.724488 records/second
# [04/14/2020 02:36:06 INFO 139834076616512] #quality_metric: host=algo-1, epoch=9, batch=0 train binary_classification_accuracy <score>=0.719
# [04/14/2020 02:36:06 INFO 139834076616512] #quality_metric: host=algo-1, epoch=9, batch=0 train binary_classification_cross_entropy <loss>=0.617716186523
# [04/14/2020 02:36:06 INFO 139834076616512] #quality_metric: host=algo-1, epoch=9, batch=0 train binary_f_1.000 <score>=0.752422907489
# [2020-04-14 02:36:07.178] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 20, "duration": 693, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=9, train binary_classification_accuracy <score>=0.709593406593
# [04/14/2020 02:36:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=9, train binary_classification_cross_entropy <loss>=0.614415394542
# [04/14/2020 02:36:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=9, train binary_f_1.000 <score>=0.766093413937
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 696.4900493621826, "sum": 696.4900493621826, "min": 696.4900493621826}}, "EndTime": 1586831767.179329, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831766.481966}
#
# [04/14/2020 02:36:07 INFO 139834076616512] #progress_metric: host=algo-1, completed 10 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 911, "sum": 911.0, "min": 911}, "Total Records Seen": {"count": 1, "max": 906700, "sum": 906700.0, "min": 906700}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1586831767.179616, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 9}, "StartTime": 1586831766.482802}
#
# [04/14/2020 02:36:07 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=129947.095684 records/second
# [04/14/2020 02:36:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=10, batch=0 train binary_classification_accuracy <score>=0.719
# [04/14/2020 02:36:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=10, batch=0 train binary_classification_cross_entropy <loss>=0.612339294434
# [04/14/2020 02:36:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=10, batch=0 train binary_f_1.000 <score>=0.751107174491
# [2020-04-14 02:36:07.859] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 22, "duration": 677, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=10, train binary_classification_accuracy <score>=0.71332967033
# [04/14/2020 02:36:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=10, train binary_classification_cross_entropy <loss>=0.609306093991
# [04/14/2020 02:36:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=10, train binary_f_1.000 <score>=0.766961757323
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 680.4318428039551, "sum": 680.4318428039551, "min": 680.4318428039551}}, "EndTime": 1586831767.860817, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831767.179421}
#
# [04/14/2020 02:36:07 INFO 139834076616512] #progress_metric: host=algo-1, completed 11 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1002, "sum": 1002.0, "min": 1002}, "Total Records Seen": {"count": 1, "max": 997270, "sum": 997270.0, "min": 997270}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1586831767.861171, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 10}, "StartTime": 1586831767.180347}
#
# [04/14/2020 02:36:07 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=133002.068244 records/second
# [04/14/2020 02:36:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=11, batch=0 train binary_classification_accuracy <score>=0.725
# [04/14/2020 02:36:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=11, batch=0 train binary_classification_cross_entropy <loss>=0.607392822266
# [04/14/2020 02:36:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=11, batch=0 train binary_f_1.000 <score>=0.755120213713
# [2020-04-14 02:36:08.547] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 24, "duration": 683, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:08 INFO 139834076616512] #quality_metric: host=algo-1, epoch=11, train binary_classification_accuracy <score>=0.716483516484
# [04/14/2020 02:36:08 INFO 139834076616512] #quality_metric: host=algo-1, epoch=11, train binary_classification_cross_entropy <loss>=0.604599700592
# [04/14/2020 02:36:08 INFO 139834076616512] #quality_metric: host=algo-1, epoch=11, train binary_f_1.000 <score>=0.767726601606
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 686.3679885864258, "sum": 686.3679885864258, "min": 686.3679885864258}}, "EndTime": 1586831768.548385, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831767.860902}
#
# [04/14/2020 02:36:08 INFO 139834076616512] #progress_metric: host=algo-1, completed 12 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1093, "sum": 1093.0, "min": 1093}, "Total Records Seen": {"count": 1, "max": 1087840, "sum": 1087840.0, "min": 1087840}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1586831768.548651, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 11}, "StartTime": 1586831767.861978}
#
# [04/14/2020 02:36:08 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=131864.989852 records/second
# [04/14/2020 02:36:08 INFO 139834076616512] #quality_metric: host=algo-1, epoch=12, batch=0 train binary_classification_accuracy <score>=0.729
# [04/14/2020 02:36:08 INFO 139834076616512] #quality_metric: host=algo-1, epoch=12, batch=0 train binary_classification_cross_entropy <loss>=0.602835571289
# [04/14/2020 02:36:08 INFO 139834076616512] #quality_metric: host=algo-1, epoch=12, batch=0 train binary_f_1.000 <score>=0.756950672646
# [2020-04-14 02:36:09.201] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 26, "duration": 650, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:09 INFO 139834076616512] #quality_metric: host=algo-1, epoch=12, train binary_classification_accuracy <score>=0.719164835165
# [04/14/2020 02:36:09 INFO 139834076616512] #quality_metric: host=algo-1, epoch=12, train binary_classification_cross_entropy <loss>=0.600259766966
# [04/14/2020 02:36:09 INFO 139834076616512] #quality_metric: host=algo-1, epoch=12, train binary_f_1.000 <score>=0.768350827577
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 653.0280113220215, "sum": 653.0280113220215, "min": 653.0280113220215}}, "EndTime": 1586831769.202375, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831768.54847}
#
# [04/14/2020 02:36:09 INFO 139834076616512] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1184, "sum": 1184.0, "min": 1184}, "Total Records Seen": {"count": 1, "max": 1178410, "sum": 1178410.0, "min": 1178410}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1586831769.202669, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 12}, "StartTime": 1586831768.549314}
#
# [04/14/2020 02:36:09 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=138593.291275 records/second
# [04/14/2020 02:36:09 INFO 139834076616512] #quality_metric: host=algo-1, epoch=13, batch=0 train binary_classification_accuracy <score>=0.73
# [04/14/2020 02:36:09 INFO 139834076616512] #quality_metric: host=algo-1, epoch=13, batch=0 train binary_classification_cross_entropy <loss>=0.598629150391
# [04/14/2020 02:36:09 INFO 139834076616512] #quality_metric: host=algo-1, epoch=13, batch=0 train binary_f_1.000 <score>=0.755877034358
# [2020-04-14 02:36:09.876] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 28, "duration": 670, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:09 INFO 139834076616512] #quality_metric: host=algo-1, epoch=13, train binary_classification_accuracy <score>=0.720769230769
# [04/14/2020 02:36:09 INFO 139834076616512] #quality_metric: host=algo-1, epoch=13, train binary_classification_cross_entropy <loss>=0.596252087939
# [04/14/2020 02:36:09 INFO 139834076616512] #quality_metric: host=algo-1, epoch=13, train binary_f_1.000 <score>=0.768300689353
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 673.4578609466553, "sum": 673.4578609466553, "min": 673.4578609466553}}, "EndTime": 1586831769.876811, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831769.202468}
#
# [04/14/2020 02:36:09 INFO 139834076616512] #progress_metric: host=algo-1, completed 14 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1275, "sum": 1275.0, "min": 1275}, "Total Records Seen": {"count": 1, "max": 1268980, "sum": 1268980.0, "min": 1268980}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1586831769.877099, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 13}, "StartTime": 1586831769.203317}
#
# [04/14/2020 02:36:09 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=134390.017873 records/second
# [04/14/2020 02:36:09 INFO 139834076616512] #quality_metric: host=algo-1, epoch=14, batch=0 train binary_classification_accuracy <score>=0.734
# [04/14/2020 02:36:09 INFO 139834076616512] #quality_metric: host=algo-1, epoch=14, batch=0 train binary_classification_cross_entropy <loss>=0.59473828125
# [04/14/2020 02:36:09 INFO 139834076616512] #quality_metric: host=algo-1, epoch=14, batch=0 train binary_f_1.000 <score>=0.756855575868
# [2020-04-14 02:36:10.550] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 30, "duration": 671, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:10 INFO 139834076616512] #quality_metric: host=algo-1, epoch=14, train binary_classification_accuracy <score>=0.722307692308
# [04/14/2020 02:36:10 INFO 139834076616512] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy <loss>=0.59254500169
# [04/14/2020 02:36:10 INFO 139834076616512] #quality_metric: host=algo-1, epoch=14, train binary_f_1.000 <score>=0.768471010775
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 673.3829975128174, "sum": 673.3829975128174, "min": 673.3829975128174}}, "EndTime": 1586831770.551205, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831769.876905}
#
# [04/14/2020 02:36:10 INFO 139834076616512] #progress_metric: host=algo-1, completed 15 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1366, "sum": 1366.0, "min": 1366}, "Total Records Seen": {"count": 1, "max": 1359550, "sum": 1359550.0, "min": 1359550}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 16, "sum": 16.0, "min": 16}}, "EndTime": 1586831770.551502, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 14}, "StartTime": 1586831769.877784}
#
# [04/14/2020 02:36:10 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=134401.762105 records/second
# [04/14/2020 02:36:10 INFO 139834076616512] #quality_metric: host=algo-1, epoch=15, batch=0 train binary_classification_accuracy <score>=0.733
# [04/14/2020 02:36:10 INFO 139834076616512] #quality_metric: host=algo-1, epoch=15, batch=0 train binary_classification_cross_entropy <loss>=0.591130859375
# [04/14/2020 02:36:10 INFO 139834076616512] #quality_metric: host=algo-1, epoch=15, batch=0 train binary_f_1.000 <score>=0.755270394134
# [2020-04-14 02:36:11.238] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 32, "duration": 684, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:11 INFO 139834076616512] #quality_metric: host=algo-1, epoch=15, train binary_classification_accuracy <score>=0.724076923077
# [04/14/2020 02:36:11 INFO 139834076616512] #quality_metric: host=algo-1, epoch=15, train binary_classification_cross_entropy <loss>=0.589109509143
# [04/14/2020 02:36:11 INFO 139834076616512] #quality_metric: host=algo-1, epoch=15, train binary_f_1.000 <score>=0.769021314175
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 686.7661476135254, "sum": 686.7661476135254, "min": 686.7661476135254}}, "EndTime": 1586831771.238953, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831770.551307}
#
# [04/14/2020 02:36:11 INFO 139834076616512] #progress_metric: host=algo-1, completed 16 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1457, "sum": 1457.0, "min": 1457}, "Total Records Seen": {"count": 1, "max": 1450120, "sum": 1450120.0, "min": 1450120}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1586831771.239218, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 15}, "StartTime": 1586831770.55215}
#
# [04/14/2020 02:36:11 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=131793.393117 records/second
# [04/14/2020 02:36:11 INFO 139834076616512] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_classification_accuracy <score>=0.73
# [04/14/2020 02:36:11 INFO 139834076616512] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_classification_cross_entropy <loss>=0.587778015137
# [04/14/2020 02:36:11 INFO 139834076616512] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_f_1.000 <score>=0.750922509225
# [2020-04-14 02:36:11.930] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 34, "duration": 689, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:11 INFO 139834076616512] #quality_metric: host=algo-1, epoch=16, train binary_classification_accuracy <score>=0.725252747253
# [04/14/2020 02:36:11 INFO 139834076616512] #quality_metric: host=algo-1, epoch=16, train binary_classification_cross_entropy <loss>=0.585919196831
# [04/14/2020 02:36:11 INFO 139834076616512] #quality_metric: host=algo-1, epoch=16, train binary_f_1.000 <score>=0.768979154347
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 691.436767578125, "sum": 691.436767578125, "min": 691.436767578125}}, "EndTime": 1586831771.931336, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831771.239032}
#
# [04/14/2020 02:36:11 INFO 139834076616512] #progress_metric: host=algo-1, completed 17 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1548, "sum": 1548.0, "min": 1548}, "Total Records Seen": {"count": 1, "max": 1540690, "sum": 1540690.0, "min": 1540690}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 18, "sum": 18.0, "min": 18}}, "EndTime": 1586831771.931622, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 16}, "StartTime": 1586831771.239863}
#
# [04/14/2020 02:36:11 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=130897.394265 records/second
# [04/14/2020 02:36:11 INFO 139834076616512] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_classification_accuracy <score>=0.729
# [04/14/2020 02:36:11 INFO 139834076616512] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_classification_cross_entropy <loss>=0.584653625488
# [04/14/2020 02:36:11 INFO 139834076616512] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_f_1.000 <score>=0.749306197965
# [2020-04-14 02:36:12.606] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 672, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:36:12 INFO 139834076616512] #quality_metric: host=algo-1, epoch=17, train binary_classification_accuracy <score>=0.726340659341
# [04/14/2020 02:36:12 INFO 139834076616512] #quality_metric: host=algo-1, epoch=17, train binary_classification_cross_entropy <loss>=0.582950161106
# [04/14/2020 02:36:12 INFO 139834076616512] #quality_metric: host=algo-1, epoch=17, train binary_f_1.000 <score>=0.769162317739
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 674.6609210968018, "sum": 674.6609210968018, "min": 674.6609210968018}}, "EndTime": 1586831772.607029, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831771.931426}
#
# [04/14/2020 02:36:12 INFO 139834076616512] #progress_metric: host=algo-1, completed 18 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1639, "sum": 1639.0, "min": 1639}, "Total Records Seen": {"count": 1, "max": 1631260, "sum": 1631260.0, "min": 1631260}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 19, "sum": 19.0, "min": 19}}, "EndTime": 1586831772.60732, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 17}, "StartTime": 1586831771.932331}
#
# [04/14/2020 02:36:12 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=134154.142166 records/second
# [04/14/2020 02:36:12 INFO 139834076616512] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_classification_accuracy <score>=0.733
# [04/14/2020 02:36:12 INFO 139834076616512] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_classification_cross_entropy <loss>=0.58173449707
# [04/14/2020 02:36:12 INFO 139834076616512] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_f_1.000 <score>=0.751627906977
# [2020-04-14 02:36:13.326] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 716, "num_examples": 91, "num_bytes": 5796480}
# ...
#
# [04/14/2020 02:37:04 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=134627.964991 records/second
# [04/14/2020 02:37:04 INFO 139834076616512] #quality_metric: host=algo-1, epoch=95, batch=0 train binary_classification_accuracy <score>=0.758
# [04/14/2020 02:37:04 INFO 139834076616512] #quality_metric: host=algo-1, epoch=95, batch=0 train binary_classification_cross_entropy <loss>=0.508373626709
# [04/14/2020 02:37:04 INFO 139834076616512] #quality_metric: host=algo-1, epoch=95, batch=0 train binary_f_1.000 <score>=0.767754318618
# [2020-04-14 02:37:05.217] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 192, "duration": 658, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:37:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=95, train binary_classification_accuracy <score>=0.750153846154
# [04/14/2020 02:37:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=95, train binary_classification_cross_entropy <loss>=0.515218102088
# [04/14/2020 02:37:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=95, train binary_f_1.000 <score>=0.780005418586
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 660.7248783111572, "sum": 660.7248783111572, "min": 660.7248783111572}}, "EndTime": 1586831825.218337, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831824.556677}
#
# [04/14/2020 02:37:05 INFO 139834076616512] #progress_metric: host=algo-1, completed 96 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 8737, "sum": 8737.0, "min": 8737}, "Total Records Seen": {"count": 1, "max": 8695720, "sum": 8695720.0, "min": 8695720}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 97, "sum": 97.0, "min": 97}}, "EndTime": 1586831825.218598, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 95}, "StartTime": 1586831824.557574}
#
# [04/14/2020 02:37:05 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=136987.74514 records/second
# [04/14/2020 02:37:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=96, batch=0 train binary_classification_accuracy <score>=0.76
# [04/14/2020 02:37:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=96, batch=0 train binary_classification_cross_entropy <loss>=0.507963470459
# [04/14/2020 02:37:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=96, batch=0 train binary_f_1.000 <score>=0.769673704415
# [2020-04-14 02:37:05.885] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 194, "duration": 664, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:37:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=96, train binary_classification_accuracy <score>=0.750263736264
# [04/14/2020 02:37:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=96, train binary_classification_cross_entropy <loss>=0.514882988228
# [04/14/2020 02:37:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=96, train binary_f_1.000 <score>=0.780085155796
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 666.8210029602051, "sum": 666.8210029602051, "min": 666.8210029602051}}, "EndTime": 1586831825.886101, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831825.218419}
#
# [04/14/2020 02:37:05 INFO 139834076616512] #progress_metric: host=algo-1, completed 97 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 8828, "sum": 8828.0, "min": 8828}, "Total Records Seen": {"count": 1, "max": 8786290, "sum": 8786290.0, "min": 8786290}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 98, "sum": 98.0, "min": 98}}, "EndTime": 1586831825.886329, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 96}, "StartTime": 1586831825.219248}
#
# [04/14/2020 02:37:05 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=135746.627411 records/second
# [04/14/2020 02:37:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=97, batch=0 train binary_classification_accuracy <score>=0.76
# [04/14/2020 02:37:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=97, batch=0 train binary_classification_cross_entropy <loss>=0.50755670166
# [04/14/2020 02:37:05 INFO 139834076616512] #quality_metric: host=algo-1, epoch=97, batch=0 train binary_f_1.000 <score>=0.769673704415
# [2020-04-14 02:37:06.546] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 196, "duration": 657, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:37:06 INFO 139834076616512] #quality_metric: host=algo-1, epoch=97, train binary_classification_accuracy <score>=0.750296703297
# [04/14/2020 02:37:06 INFO 139834076616512] #quality_metric: host=algo-1, epoch=97, train binary_classification_cross_entropy <loss>=0.514550657168
# [04/14/2020 02:37:06 INFO 139834076616512] #quality_metric: host=algo-1, epoch=97, train binary_f_1.000 <score>=0.780112058371
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 660.1009368896484, "sum": 660.1009368896484, "min": 660.1009368896484}}, "EndTime": 1586831826.547135, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831825.88618}
#
# [04/14/2020 02:37:06 INFO 139834076616512] #progress_metric: host=algo-1, completed 98 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 8919, "sum": 8919.0, "min": 8919}, "Total Records Seen": {"count": 1, "max": 8876860, "sum": 8876860.0, "min": 8876860}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 99, "sum": 99.0, "min": 99}}, "EndTime": 1586831826.54738, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 97}, "StartTime": 1586831825.887004}
#
# [04/14/2020 02:37:06 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=137123.826549 records/second
# [04/14/2020 02:37:06 INFO 139834076616512] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_classification_accuracy <score>=0.76
# [04/14/2020 02:37:06 INFO 139834076616512] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_classification_cross_entropy <loss>=0.507153259277
# [04/14/2020 02:37:06 INFO 139834076616512] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_f_1.000 <score>=0.769673704415
# [2020-04-14 02:37:07.204] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 198, "duration": 654, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:37:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=98, train binary_classification_accuracy <score>=0.750274725275
# [04/14/2020 02:37:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=98, train binary_classification_cross_entropy <loss>=0.514220961686
# [04/14/2020 02:37:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=98, train binary_f_1.000 <score>=0.780096960548
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 656.8150520324707, "sum": 656.8150520324707, "min": 656.8150520324707}}, "EndTime": 1586831827.204853, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831826.547212}
#
# [04/14/2020 02:37:07 INFO 139834076616512] #progress_metric: host=algo-1, completed 99 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 9010, "sum": 9010.0, "min": 9010}, "Total Records Seen": {"count": 1, "max": 8967430, "sum": 8967430.0, "min": 8967430}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 100, "sum": 100.0, "min": 100}}, "EndTime": 1586831827.205107, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 98}, "StartTime": 1586831826.548001}
#
# [04/14/2020 02:37:07 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=137805.65971 records/second
# [04/14/2020 02:37:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_classification_accuracy <score>=0.761
# [04/14/2020 02:37:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_classification_cross_entropy <loss>=0.506752929687
# [04/14/2020 02:37:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_f_1.000 <score>=0.770853307766
# [2020-04-14 02:37:07.864] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 200, "duration": 657, "num_examples": 91, "num_bytes": 5796480}
# [04/14/2020 02:37:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=99, train binary_classification_accuracy <score>=0.75043956044
# [04/14/2020 02:37:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=99, train binary_classification_cross_entropy <loss>=0.513893749866
# [04/14/2020 02:37:07 INFO 139834076616512] #quality_metric: host=algo-1, epoch=99, train binary_f_1.000 <score>=0.780248490478
# [04/14/2020 02:37:07 INFO 139834076616512] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.75043956044
# [04/14/2020 02:37:07 INFO 139834076616512] #quality_metric: host=algo-1, train binary_classification_cross_entropy <loss>=0.513893749866
# [04/14/2020 02:37:07 INFO 139834076616512] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.780248490478
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 659.2791080474854, "sum": 659.2791080474854, "min": 659.2791080474854}}, "EndTime": 1586831827.865023, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831827.204937}
#
# [04/14/2020 02:37:07 INFO 139834076616512] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 9101, "sum": 9101.0, "min": 9101}, "Total Records Seen": {"count": 1, "max": 9058000, "sum": 9058000.0, "min": 9058000}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 101, "sum": 101.0, "min": 101}}, "EndTime": 1586831827.865249, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 99}, "StartTime": 1586831827.205715}
#
# [04/14/2020 02:37:07 INFO 139834076616512] #throughput_metric: host=algo-1, train throughput=137300.710318 records/second
# [04/14/2020 02:37:07 WARNING 139834076616512] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/14/2020 02:37:07 INFO 139834076616512] Pulling entire model from kvstore to finalize
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 2.407073974609375, "sum": 2.407073974609375, "min": 2.407073974609375}}, "EndTime": 1586831827.867943, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831827.8651}
#
# [04/14/2020 02:37:07 INFO 139834076616512] Saved checkpoint to "/tmp/tmpHaLOyd/state-0001.params"
# [2020-04-14 02:37:07.874] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 68255, "num_examples": 1, "num_bytes": 64000}
# [2020-04-14 02:37:07.919] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 44, "num_examples": 10, "num_bytes": 603520}
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 10, "sum": 10.0, "min": 10}, "Number of Batches Since Last Reset": {"count": 1, "max": 10, "sum": 10.0, "min": 10}, "Number of Records Since Last Reset": {"count": 1, "max": 9430, "sum": 9430.0, "min": 9430}, "Total Batches Seen": {"count": 1, "max": 10, "sum": 10.0, "min": 10}, "Total Records Seen": {"count": 1, "max": 9430, "sum": 9430.0, "min": 9430}, "Max Records Seen Between Resets": {"count": 1, "max": 9430, "sum": 9430.0, "min": 9430}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1586831827.919583, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831827.874764}
#
# [04/14/2020 02:37:07 INFO 139834076616512] #test_score (algo-1) : ('binary_classification_accuracy', 0.6953340402969247)
# [04/14/2020 02:37:07 INFO 139834076616512] #test_score (algo-1) : ('binary_classification_cross_entropy', 0.578790852778284)
# [04/14/2020 02:37:07 INFO 139834076616512] #test_score (algo-1) : ('binary_f_1.000', 0.7362042053071344)
# [04/14/2020 02:37:07 INFO 139834076616512] #quality_metric: host=algo-1, test binary_classification_accuracy <score>=0.695334040297
# [04/14/2020 02:37:07 INFO 139834076616512] #quality_metric: host=algo-1, test binary_classification_cross_entropy <loss>=0.578790852778
# [04/14/2020 02:37:07 INFO 139834076616512] #quality_metric: host=algo-1, test binary_f_1.000 <score>=0.736204205307
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 68361.5140914917, "sum": 68361.5140914917, "min": 68361.5140914917}, "setuptime": {"count": 1, "max": 51.1631965637207, "sum": 51.1631965637207, "min": 51.1631965637207}}, "EndTime": 1586831827.920416, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1586831827.868008}
# 2020-04-14 02:37:15 Uploading - Uploading generated training model
# 2020-04-14 02:37:15 Completed - Training job completed
# Training seconds: 141
# Billable seconds: 141

# %% [markdown]
# The FM model cannot predict several movie_id with the user_id as input, thus we need to further extend this model to satisfy the requirement of this coursework.

# %% [markdown]
# ## KNN model
#
# To further build on the recommendor, I would like to extend FM model to predict top 5 recommendations using SageMaker's built-in model KNN and Batch Transform.

# %%
! pip install mxnet
# Out:
# Collecting mxnet
#   Downloading https://files.pythonhosted.org/packages/81/f5/d79b5b40735086ff1100c680703e0f3efc830fa455e268e9e96f3c857e93/mxnet-1.6.0-py2.py3-none-any.whl (68.7MB)
#     100% |████████████████████████████████| 68.7MB 704kB/s eta 0:00:01
# Collecting graphviz<0.9.0,>=0.8.1 (from mxnet)
#   Downloading https://files.pythonhosted.org/packages/53/39/4ab213673844e0c004bed8a0781a0721a3f6bb23eb8854ee75c236428892/graphviz-0.8.4-py2.py3-none-any.whl
# Collecting numpy<2.0.0,>1.16.0 (from mxnet)
#   Downloading https://files.pythonhosted.org/packages/07/08/a549ba8b061005bb629b76adc000f3caaaf881028b963c2e18f811c6edc1/numpy-1.18.2-cp36-cp36m-manylinux1_x86_64.whl (20.2MB)
#     100% |████████████████████████████████| 20.2MB 2.5MB/s eta 0:00:01
# Requirement already satisfied: requests<3,>=2.20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from mxnet) (2.20.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet) (1.23)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet) (2019.11.28)
# Installing collected packages: graphviz, numpy, mxnet
#   Found existing installation: numpy 1.14.3
#     Uninstalling numpy-1.14.3:
#       Successfully uninstalled numpy-1.14.3
# Successfully installed graphviz-0.8.4 mxnet-1.6.0 numpy-1.18.2
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ### Download the model data
# Since we have already have our FM model saved in sagemaker, we could download the model data and repackage it to fit a KNN model.

# %%
# Define model path
import mxnet as mx
model_file_name = "model.tar.gz"
model_full_path = fm.output_path +"/"+ fm.latest_training_job.job_name +"/output/"+model_file_name
#model_full_path = 's3://movie-recom-sys-0420/fm/output/factorization-machines-2020-04-06-06-55-06-671/output/model.tar.gz'
print("Model Path: ", model_full_path)
# Out:
# Model Path:  s3://movie-recom-sys-0420/fm/output/factorization-machines-2020-04-14-02-33-06-151/output/model.tar.gz

# %%
#Download FM model 
import os
# %cd ..
os.system('aws s3 cp '+ model_full_path + ' ./')
# Out:
# /home/ec2-user/SageMaker
# 0

# %%
#Extract model file for loading to MXNet
os.system('tar xzvf '+model_file_name)
os.system("unzip -o model_algo-1")
os.system("mv symbol.json model-symbol.json")
os.system("mv params model-0000.params")
# Out:
# 0

# %% [markdown]
# ### Extract model data to create user and item latent matrices

# %%
#Extract model data
m = mx.module.Module.load('./model', 0, False, label_names=['out_label'])
V = m._arg_params['v'].asnumpy()
w = m._arg_params['w1_weight'].asnumpy()
b = m._arg_params['w0_weight'].asnumpy()

# item latent matrix - concat(V[i], w[i]).  
knn_item_matrix = np.concatenate((V[nb_users:], w[nb_users:]), axis=1)
knn_train_label = np.arange(1,nb_movies+1)

#user latent matrix - concat (V[u], 1) 
ones = np.ones(nb_users).reshape((nb_users, 1))
knn_user_matrix = np.concatenate((V[:nb_users], ones), axis=1)

# %% [markdown]
# ### Build K-Nearest-Neighbour Model
#
# We upload the model input data to S3, create a KNN model and save the same. Saving the model will aid in calling batch transform down the line or even deploying it as an end point for real-time inference.

# %%
print('KNN train features shape = ', knn_item_matrix.shape)
knn_prefix = 'knn'
knn_output_prefix  = 's3://{}/{}/output'.format(bucket, knn_prefix)
knn_train_data_path = writeDatasetToProtobuf(knn_item_matrix, bucket, knn_prefix, train_key, "dense", knn_train_label)
print('uploaded KNN train data: {}'.format(knn_train_data_path))

nb_recommendations = 5

# set up the estimator
knn = sagemaker.estimator.Estimator(get_image_uri(boto3.Session().region_name, "knn"),
    get_execution_role(),
    train_instance_count=1,
    train_instance_type=instance_type,
    output_path=knn_output_prefix,
    sagemaker_session=sagemaker.Session())

knn.set_hyperparameters(feature_dim=knn_item_matrix.shape[1], k=nb_recommendations, index_metric="INNER_PRODUCT", predictor_type='classifier', sample_size=200000)
fit_input = {'train': knn_train_data_path}
knn.fit(fit_input)
knn_model_name =  knn.latest_training_job.job_name
print("created model: ", knn_model_name)

# save the model so that we can reference it in the next step during batch inference
sm = boto3.client(service_name='sagemaker')
primary_container = {
    'Image': knn.image_name,
    'ModelDataUrl': knn.model_data,
}

knn_model = sm.create_model(
        ModelName = knn.latest_training_job.job_name,
        ExecutionRoleArn = knn.role,
        PrimaryContainer = primary_container)
print("saved the model")
# Out:
# KNN train features shape =  (1682, 65)
# uploaded KNN train data: s3://movie-recom-sys-0420/knn/train.protobuf
# 2020-04-14 02:50:59 Starting - Starting the training job...
# 2020-04-14 02:51:00 Starting - Launching requested ML instances......
# 2020-04-14 02:52:24 Starting - Preparing the instances for training......
# 2020-04-14 02:53:29 Downloading - Downloading input data
# 2020-04-14 02:53:29 Training - Downloading the training image......
# 2020-04-14 02:54:28 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [04/14/2020 02:54:20 INFO 140145955112768] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'index_metric': u'L2', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'_log_level': u'info', u'faiss_index_ivf_nlists': u'auto', u'epochs': u'1', u'index_type': u'faiss.Flat', u'_faiss_index_nprobe': u'5', u'_kvstore': u'dist_async', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000'}
# [04/14/2020 02:54:20 INFO 140145955112768] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'sample_size': u'200000', u'feature_dim': u'65', u'index_metric': u'INNER_PRODUCT', u'predictor_type': u'classifier', u'k': u'5'}
# [04/14/2020 02:54:20 INFO 140145955112768] Final configuration: {u'index_metric': u'INNER_PRODUCT', u'predictor_type': u'classifier', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'_log_level': u'info', u'feature_dim': u'65', u'faiss_index_ivf_nlists': u'auto', u'sample_size': u'200000', u'epochs': u'1', u'index_type': u'faiss.Flat', u'_faiss_index_nprobe': u'5', u'_kvstore': u'dist_async', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'k': u'5'}
# [04/14/2020 02:54:20 WARNING 140145955112768] Loggers have already been setup.
# [04/14/2020 02:54:21 INFO 140145955112768] Launching parameter server for role scheduler
# [04/14/2020 02:54:21 INFO 140145955112768] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/3f2075f6-fea4-458e-a9ee-f823178d252f', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-2', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'knn-2020-04-14-02-50-59-332', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-219-126.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/13b8795f-bdf4-496f-95db-1f8d246bf83e', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:780261970141:training-job/knn-2020-04-14-02-50-59-332', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/14/2020 02:54:21 INFO 140145955112768] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/3f2075f6-fea4-458e-a9ee-f823178d252f', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.219.126', 'AWS_REGION': 'us-east-2', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'knn-2020-04-14-02-50-59-332', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-219-126.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/13b8795f-bdf4-496f-95db-1f8d246bf83e', 'DMLC_ROLE': 'scheduler', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:780261970141:training-job/knn-2020-04-14-02-50-59-332', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/14/2020 02:54:21 INFO 140145955112768] Launching parameter server for role server
# [04/14/2020 02:54:21 INFO 140145955112768] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/3f2075f6-fea4-458e-a9ee-f823178d252f', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-2', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'knn-2020-04-14-02-50-59-332', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-219-126.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/13b8795f-bdf4-496f-95db-1f8d246bf83e', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:780261970141:training-job/knn-2020-04-14-02-50-59-332', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/14/2020 02:54:21 INFO 140145955112768] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/3f2075f6-fea4-458e-a9ee-f823178d252f', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.219.126', 'AWS_REGION': 'us-east-2', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'knn-2020-04-14-02-50-59-332', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-219-126.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/13b8795f-bdf4-496f-95db-1f8d246bf83e', 'DMLC_ROLE': 'server', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:780261970141:training-job/knn-2020-04-14-02-50-59-332', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [04/14/2020 02:54:21 INFO 140145955112768] Environment: {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/3f2075f6-fea4-458e-a9ee-f823178d252f', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '1', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.219.126', 'AWS_REGION': 'us-east-2', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'knn-2020-04-14-02-50-59-332', 'HOME': '/root', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-219-126.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/13b8795f-bdf4-496f-95db-1f8d246bf83e', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:780261970141:training-job/knn-2020-04-14-02-50-59-332', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# Process 60 is a shell:scheduler.
# Process 69 is a shell:server.
# Process 1 is a worker.
# [04/14/2020 02:54:21 INFO 140145955112768] Using default worker.
# [04/14/2020 02:54:21 INFO 140145955112768] nvidia-smi took: 0.0252070426941 secs to identify 0 gpus
# [04/14/2020 02:54:21 INFO 140145955112768] Create Store: dist_async
# [04/14/2020 02:54:22 ERROR 140145955112768] nvidia-smi: failed to run (127): /bin/sh: nvidia-smi: command not found
# [04/14/2020 02:54:22 INFO 140145955112768] Using per-worker sample size = 200000 (Available virtual memory = 15174549504 bytes, GPU free memory = 0 bytes, number of workers = 1). If an out-of-memory error occurs, choose a larger instance type, use dimension reduction, decrease sample_size, and/or decrease mini_batch_size.
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1586832863.063779, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/KNN"}, "StartTime": 1586832863.06372}
#
# [2020-04-14 02:54:23.064] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 1221, "num_examples": 1, "num_bytes": 518056}
# [2020-04-14 02:54:23.086] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 22, "num_examples": 1, "num_bytes": 518056}
# [04/14/2020 02:54:23 INFO 140145955112768] push reservoir to kv... 1 num_workers 0 rank
# [04/14/2020 02:54:23 INFO 140145955112768] ...done (1682)
# [04/14/2020 02:54:23 INFO 140145955112768] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 1682, "sum": 1682.0, "min": 1682}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 1682, "sum": 1682.0, "min": 1682}, "Max Records Seen Between Resets": {"count": 1, "max": 1682, "sum": 1682.0, "min": 1682}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1586832863.115159, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KNN", "epoch": 0}, "StartTime": 1586832863.064171}
#
# [04/14/2020 02:54:23 INFO 140145955112768] #throughput_metric: host=algo-1, train throughput=32883.0086649 records/second
# [04/14/2020 02:54:23 INFO 140145955112768] pulled row count... worker 0 rows 1682
# [04/14/2020 02:54:23 INFO 140145955112768] pulled... worker 0 data (1682, 65) labels (1682, 1) nans 0
# [04/14/2020 02:54:23 INFO 140145955112768] calling index.train...
# [04/14/2020 02:54:23 INFO 140145955112768] ...done calling index.train
# [04/14/2020 02:54:23 INFO 140145955112768] calling index.add...
# [04/14/2020 02:54:23 INFO 140145955112768] ...done calling index.add
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "model.serialize.time": {"count": 1, "max": 1.680135726928711, "sum": 1.680135726928711, "min": 1.680135726928711}, "finalize.time": {"count": 1, "max": 135.76316833496094, "sum": 135.76316833496094, "min": 135.76316833496094}, "initialize.time": {"count": 1, "max": 1208.522081375122, "sum": 1208.522081375122, "min": 1208.522081375122}, "update.time": {"count": 1, "max": 50.73285102844238, "sum": 50.73285102844238, "min": 50.73285102844238}}, "EndTime": 1586832863.25305, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KNN"}, "StartTime": 1586832861.839985}
#
# [04/14/2020 02:54:23 INFO 140145955112768] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2822.0160007476807, "sum": 2822.0160007476807, "min": 2822.0160007476807}, "setuptime": {"count": 1, "max": 1056.5979480743408, "sum": 1056.5979480743408, "min": 1056.5979480743408}}, "EndTime": 1586832863.253967, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KNN"}, "StartTime": 1586832863.253148}
# 2020-04-14 02:54:34 Completed - Training job completed
# Training seconds: 71
# Billable seconds: 71
# created model:  knn-2020-04-14-02-50-59-332
# saved the model

# %% [markdown]
# ### Deploy with Batch Transformation
# we will use SageMaker's batch transform option to batch predict top X for all the users.

# %%
#upload inference data to S3
knn_batch_data_path = writeDatasetToProtobuf(knn_user_matrix, bucket, knn_prefix, train_key, "dense")
print("Batch inference data path: ",knn_batch_data_path)

# Initialize the transformer object
transformer =sagemaker.transformer.Transformer(
    base_transform_job_name="knn",
    model_name=knn_model_name,
    instance_count=1,
    instance_type=instance_type,
    output_path=knn_output_prefix,
    accept="application/jsonlines; verbose=true"
)

# Start a transform job:
transformer.transform(knn_batch_data_path, content_type='application/x-recordio-protobuf')
transformer.wait()


#Download predictions 
results_file_name = "inference_output"
inference_output_file = "knn/output/train.protobuf.out"
s3_client = boto3.client('s3')
s3_client.download_file(bucket, inference_output_file, results_file_name)
with open(results_file_name) as f:
    results = f.readlines()
# Out:
# Batch inference data path:  s3://movie-recom-sys-0420/knn/train.protobuf
# ........................
# .Docker entrypoint called with argument(s): serve
# Running default environment configuration script
# Docker entrypoint called with argument(s): serve
# Running default environment configuration script
# [04/14/2020 03:03:48 INFO 140166981982016] loaded entry point class algorithm.serve.server_config:config_api
# [04/14/2020 03:03:48 INFO 140166981982016] loading entry points
# [04/14/2020 03:03:48 INFO 140166981982016] loaded request iterator text/csv
# [04/14/2020 03:03:48 INFO 140166981982016] loaded request iterator application/x-recordio-protobuf
# [04/14/2020 03:03:48 INFO 140166981982016] loaded request iterator application/json
# [04/14/2020 03:03:48 INFO 140166981982016] loaded request iterator application/jsonlines
# [04/14/2020 03:03:48 INFO 140166981982016] loaded response encoder application/x-recordio-protobuf
# [04/14/2020 03:03:48 INFO 140166981982016] loaded response encoder application/json
# [04/14/2020 03:03:48 INFO 140166981982016] loaded response encoder application/jsonlines
# [04/14/2020 03:03:48 INFO 140166981982016] loaded entry point class algorithm:model
# [04/14/2020 03:03:48 INFO 140166981982016] Number of server workers: 1
# [2020-04-14 03:03:48 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2020-04-14 03:03:48 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2020-04-14 03:03:48 +0000] [1] [INFO] Using worker: sync
# [2020-04-14 03:03:48 +0000] [71] [INFO] Booting worker with pid: 71
# [04/14/2020 03:03:48 INFO 140166981982016] loading model...
# [04/14/2020 03:03:48 INFO 140166981982016] nvidia-smi took: 0.0251939296722 secs to identify 0 gpus
# [04/14/2020 03:03:48 INFO 140166981982016] ...model loaded.
# #metrics {"Metrics": {"execution_parameters.count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1586833428.28863, "Dimensions": {"Host": "UNKNOWN", "Operation": "scoring", "Algorithm": "KNNModel"}, "StartTime": 1586833428.279054}
#
# [2020-04-14 03:03:48.344] [tensorio] [info] epoch_stats={"data_pipeline": "/tmp/tmpfuDw9X/tmpKSxIjK", "epoch": 0, "duration": 23, "num_examples": 1, "num_bytes": 516764}
# #metrics {"Metrics": {"model.evaluate.time": {"count": 1, "max": 20.740985870361328, "sum": 20.740985870361328, "min": 20.740985870361328}, "invocations.count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1586833428.363029, "Dimensions": {"Host": "UNKNOWN", "Operation": "scoring", "Algorithm": "KNNModel"}, "StartTime": 1586833428.288739}
#
# [04/14/2020 03:03:48 INFO 140166981982016] loaded entry point class algorithm.serve.server_config:config_api
# [04/14/2020 03:03:48 INFO 140166981982016] loading entry points
# [04/14/2020 03:03:48 INFO 140166981982016] loaded request iterator text/csv
# [04/14/2020 03:03:48 INFO 140166981982016] loaded request iterator application/x-recordio-protobuf
# [04/14/2020 03:03:48 INFO 140166981982016] loaded request iterator application/json
# [04/14/2020 03:03:48 INFO 140166981982016] loaded request iterator application/jsonlines
# [04/14/2020 03:03:48 INFO 140166981982016] loaded response encoder application/x-recordio-protobuf
# [04/14/2020 03:03:48 INFO 140166981982016] loaded response encoder application/json
# [04/14/2020 03:03:48 INFO 140166981982016] loaded response encoder application/jsonlines
# [04/14/2020 03:03:48 INFO 140166981982016] loaded entry point class algorithm:model
# [04/14/2020 03:03:48 INFO 140166981982016] Number of server workers: 1
# [2020-04-14 03:03:48 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2020-04-14 03:03:48 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2020-04-14 03:03:48 +0000] [1] [INFO] Using worker: sync
# [2020-04-14 03:03:48 +0000] [71] [INFO] Booting worker with pid: 71
# [04/14/2020 03:03:48 INFO 140166981982016] loading model...
# [04/14/2020 03:03:48 INFO 140166981982016] nvidia-smi took: 0.0251939296722 secs to identify 0 gpus
# [04/14/2020 03:03:48 INFO 140166981982016] ...model loaded.
# #metrics {"Metrics": {"execution_parameters.count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1586833428.28863, "Dimensions": {"Host": "UNKNOWN", "Operation": "scoring", "Algorithm": "KNNModel"}, "StartTime": 1586833428.279054}
#
# [2020-04-14 03:03:48.344] [tensorio] [info] epoch_stats={"data_pipeline": "/tmp/tmpfuDw9X/tmpKSxIjK", "epoch": 0, "duration": 23, "num_examples": 1, "num_bytes": 516764}
# #metrics {"Metrics": {"model.evaluate.time": {"count": 1, "max": 20.740985870361328, "sum": 20.740985870361328, "min": 20.740985870361328}, "invocations.count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1586833428.363029, "Dimensions": {"Host": "UNKNOWN", "Operation": "scoring", "Algorithm": "KNNModel"}, "StartTime": 1586833428.288739}
#
# 2020-04-14T03:03:48.293:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD

# %% [markdown]
# ### User predictions

# %% [markdown]
# We now have predictions for all users. This could be directly used as an endpoint.
# If we want to see top 5 movies for users in the *user_prediction.csv*, we can load the json file into the notebook and see the results.

# %%
# User prediction path
user_pred_path = 's3://movie-recom-sys-0420/user_predictions.csv'

# Load data
user_pred = pd.read_csv(user_pred_path, header = None)
user_pred.rename(columns = {0:'user_id'}, inplace = True)
user_pred
# Out:
#    user_id
# 0      198
# 1       11
# 2      314
# 3      184
# 4      163
# 5      710
# 6      881
# 7      504
# 8      267
# 9      653

# %%
import json
test_user_idx = list(user_pred.user_id)
for idx in test_user_idx:
    pred = json.loads(results[idx])
    movie_Ids = [int(movie_id) for movie_id in pred['labels']]
    print("Recommended movie Ids for user #{} : {}".format(idx, movie_Ids))
# Out:
# Recommended movie Ids for user #198 : [357, 98, 479, 127, 483]
# Recommended movie Ids for user #11 : [22, 79, 50, 174, 64]
# Recommended movie Ids for user #314 : [64, 98, 127, 479, 483]
# Recommended movie Ids for user #184 : [98, 50, 479, 64, 483]
# Recommended movie Ids for user #163 : [125, 332, 328, 117, 121]
# Recommended movie Ids for user #710 : [98, 127, 64, 479, 483]
# Recommended movie Ids for user #881 : [172, 98, 174, 50, 64]
# Recommended movie Ids for user #504 : [332, 328, 117, 121, 300]
# Recommended movie Ids for user #267 : [357, 479, 98, 127, 483]
# Recommended movie Ids for user #653 : [172, 79, 50, 174, 64]

# %% [markdown]
# ## ALS Model

# %% [markdown]
# ### Use Sagemaker Pyspark SDK
# The SageMaker PySpark SDK provides a pyspark interface to Amazon Sagemaker, allowing me to train using the Spark Estimator API, host model on Amazon SageMaker, and make predictions using the Spark Transformer API.

# %%
import sagemaker_pyspark
from pyspark.sql import SparkSession

classpath = ":".join(sagemaker_pyspark.classpath_jars())
spark = SparkSession.builder.config("spark.driver.extraClassPath", classpath).getOrCreate()

# %%
# spark imports
from pyspark.sql import SparkSession
from pyspark.sql.functions import UserDefinedFunction, explode, desc
from pyspark.sql.types import StringType, ArrayType
from pyspark.mllib.recommendation import ALS

# %% [markdown]
# ### Data preparation
# KNN model suffered from popularity bias, cold start problem and scalability issue.Therefore, we try to improve KNN model using ALS model.
# #### Load data to RDD

# %%
# load data
movie_rating = spark.read.csv("ml-100k/u.data", sep = '\\t')

# preprocess data -- only need ["userId", "movieId", "rating"]
movie_rating = movie_rating.rdd
rating_data = movie_rating.map(lambda tokens: (int(tokens[0]), int(tokens[1]), float(tokens[2]))).cache()
# check three rows
rating_data.take(3)
# Out:
# [(196, 242, 3.0), (186, 302, 3.0), (22, 377, 1.0)]

# %% [markdown]
# #### Split data
# Now we spilt data into training/test/validation sets using 6/6/2 ratio.

# %%
train, validation, test = rating_data.randomSplit([6, 2, 2], seed=42)
# cache data
train.cache()
validation.cache()
test.cache()
# Out:
# PythonRDD[17] at RDD at PythonRDD.scala:52

# %% [markdown]
# ### ALS model selection and Evaluation
# With ALS model, we can use **grid search** to find the optimal hyperparameters.

# %%
def train_ALS(train_data, validation_data, num_iters, reg_param, ranks):
    """
    Grid Search Function to select the best model based on RMSE of hold-out data
    """
    # initial
    min_error = float('inf')
    best_rank = -1
    best_regularization = 0
    best_model = None
    for rank in ranks:
        for reg in reg_param:
            # train ALS model
            model = ALS.train(
                ratings=train_data,    # (userID, productID, rating) tuple
                iterations=num_iters,
                rank=rank,
                lambda_=reg,           # regularization param
                seed=42)
            # make prediction
            valid_data = validation_data.map(lambda p: (p[0], p[1]))
            predictions = model.predictAll(valid_data).map(lambda r: ((r[0], r[1]), r[2]))
            # get the rating result
            ratesAndPreds = validation_data.map(lambda r: ((r[0], r[1]), r[2])).join(predictions)
            # get the RMSE
            MSE = ratesAndPreds.map(lambda r: (r[1][0] - r[1][1])**2).mean()
            error = math.sqrt(MSE)
            print('{} latent factors and regularization = {}: validation RMSE is {}'.format(rank, reg, error))
            if error < min_error:
                min_error = error
                best_rank = rank
                best_regularization = reg
                best_model = model
    print('\nThe best model has {} latent factors and regularization = {}'.format(best_rank, best_regularization))
    return best_model

# %%
import time
# hyper-param config
num_iterations = 5
ranks = [10, 15, 20]
reg_params = [0.01, 0.05, 0.1]

# grid search and select best model
start_time = time.time()
final_model = train_ALS(train, validation, num_iterations, reg_params, ranks)

print ('Total Runtime: {:.2f} seconds'.format(time.time() - start_time))
# Out:
# 10 latent factors and regularization = 0.01: validation RMSE is 1.1619561194228456
# 10 latent factors and regularization = 0.05: validation RMSE is 1.0104148079567132
# 10 latent factors and regularization = 0.1: validation RMSE is 0.9627032179598456
# 15 latent factors and regularization = 0.01: validation RMSE is 1.2023807327615241
# 15 latent factors and regularization = 0.05: validation RMSE is 1.0096420541467912
# 15 latent factors and regularization = 0.1: validation RMSE is 0.9571341850451307
# 20 latent factors and regularization = 0.01: validation RMSE is 1.232445293827424
# 20 latent factors and regularization = 0.05: validation RMSE is 1.0142326998434243
# 20 latent factors and regularization = 0.1: validation RMSE is 0.9566770702589341
#
# The best model has 20 latent factors and regularization = 0.1
# Total Runtime: 24.98 seconds

# %% [markdown]
# ### Model test
# Finally, we make predictions using ALS model and test the error using the out-of-sample data.

# %%
# make prediction using test data
test_data = test.map(lambda p: (p[0], p[1]))
predictions = final_model.predictAll(test_data).map(lambda r: ((r[0], r[1]), r[2]))
# get the rating result
ratesAndPreds = test.map(lambda r: ((r[0], r[1]), r[2])).join(predictions)
# get the RMSE
MSE = ratesAndPreds.map(lambda r: (r[1][0] - r[1][1])**2).mean()
error = math.sqrt(MSE)
print('The out-of-sample RMSE of rating predictions is', round(error, 4))
# Out:
# The out-of-sample RMSE of rating predictions is 0.9539

# %% [markdown]
# I did not find built-in algorithms in sagemaker to use ALS. To use ALS in sagemaker may need to build a docker, convert what has been written above to .py file, include inference code and other files into the container, and let sagemaker run the container. I tried several times on this but somehow I did not successfully run data flow. Will look on this if more time is given.
